# %% [markdown]
# Phishing URL Detector🚨

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt

# %%
data= pd.read_csv("phishing_website_dataset.csv")

data.info()

# None of the feature is having null values😭
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 188637 entries, 0 to 188636
# Data columns (total 56 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   FILENAME                    188637 non-null  object
#  1   URL                         188637 non-null  object
#  2   URLLength                   188637 non-null  int64
#  3   Domain                      188637 non-null  object
#  4   DomainLength                188637 non-null  int64
#  5   IsDomainIP                  188637 non-null  int64
#  6   TLD                         188637 non-null  object
#  7   URLSimilarityIndex          188637 non-null  float64
#  8   CharContinuationRate        188637 non-null  float64
#  9   TLDLegitimateProb           188637 non-null  float64
#  10  URLCharProb                 188637 non-null  float64
#  11  TLDLength                   188637 non-null  int64
#  12  NoOfSubDomain               188637 non-null  int64
#  13  HasObfuscation              188637 non-null  int64
#  14  NoOfObfuscatedChar          188637 non-null  int64
#  15  ObfuscationRatio            188637 non-null  float64
#  16  NoOfLettersInURL            188637 non-null  int64
#  17  LetterRatioInURL            188637 non-null  float64
#  18  NoOfDegitsInURL             188637 non-null  int64
#  19  DegitRatioInURL             188637 non-null  float64
#  20  NoOfEqualsInURL             188637 non-null  int64
#  21  NoOfQMarkInURL              188637 non-null  int64
#  22  NoOfAmpersandInURL          188637 non-null  int64
#  23  NoOfOtherSpecialCharsInURL  188637 non-null  int64
#  24  SpacialCharRatioInURL       188637 non-null  float64
#  25  IsHTTPS                     188637 non-null  int64
#  26  LineOfCode                  188637 non-null  int64
#  27  LargestLineLength           188637 non-null  int64
#  28  HasTitle                    188637 non-null  int64
#  29  Title                       188637 non-null  object
#  30  DomainTitleMatchScore       188637 non-null  float64
#  31  URLTitleMatchScore          188637 non-null  float64
#  32  HasFavicon                  188637 non-null  int64
#  33  Robots                      188637 non-null  int64
#  34  IsResponsive                188637 non-null  int64
#  35  NoOfURLRedirect             188637 non-null  int64
#  36  NoOfSelfRedirect            188637 non-null  int64
#  37  HasDescription              188637 non-null  int64
#  38  NoOfPopup                   188637 non-null  int64
#  39  NoOfiFrame                  188637 non-null  int64
#  40  HasExternalFormSubmit       188637 non-null  int64
#  41  HasSocialNet                188637 non-null  int64
#  42  HasSubmitButton             188637 non-null  int64
#  43  HasHiddenFields             188637 non-null  int64
#  44  HasPasswordField            188637 non-null  int64
#  45  Bank                        188637 non-null  int64
#  46  Pay                         188637 non-null  int64
#  47  Crypto                      188637 non-null  int64
#  48  HasCopyrightInfo            188637 non-null  int64
#  49  NoOfImage                   188637 non-null  int64
#  50  NoOfCSS                     188637 non-null  int64
#  51  NoOfJS                      188637 non-null  int64
#  52  NoOfSelfRef                 188637 non-null  int64
#  53  NoOfEmptyRef                188637 non-null  int64
#  54  NoOfExternalRef             188637 non-null  int64
#  55  label                       188637 non-null  int64
# dtypes: float64(10), int64(41), object(5)
# memory usage: 80.6+ MB

# %%
data.head()
# Out:
#      FILENAME                                 URL  URLLength  \
# 0  521848.txt    https://www.southbankmosaics.com         31
# 1   31372.txt            https://www.uni-mainz.de         23
# 2  597387.txt      https://www.voicefmradio.co.uk         29
# 3  554095.txt         https://www.sfnmjournal.com         26
# 4  151578.txt  https://www.rewildingargentina.org         33
#
#                        Domain  DomainLength  IsDomainIP  TLD  \
# 0    www.southbankmosaics.com            24           0  com
# 1            www.uni-mainz.de            16           0   de
# 2      www.voicefmradio.co.uk            22           0   uk
# 3         www.sfnmjournal.com            19           0  com
# 4  www.rewildingargentina.org            26           0  org
#
#    URLSimilarityIndex  CharContinuationRate  TLDLegitimateProb  ...  Pay  \
# 0               100.0              1.000000           0.522907  ...    0
# 1               100.0              0.666667           0.032650  ...    0
# 2               100.0              0.866667           0.028555  ...    0
# 3               100.0              1.000000           0.522907  ...    1
# 4               100.0              1.000000           0.079963  ...    1
#
#    Crypto  HasCopyrightInfo  NoOfImage  NoOfCSS  NoOfJS  NoOfSelfRef  \
# 0       0                 1         34       20      28          119
# 1       0                 1         50        9       8           39
# 2       0                 1         10        2       7           42
# 3       1                 1          3       27      15           22
# 4       0                 1        244       15      34           72
#
#    NoOfEmptyRef  NoOfExternalRef  label
# 0             0              124      1
# 1             0              217      1
# 2             2                5      1
# 3             1               31      1
# 4             1               85      1
#
# [5 rows x 56 columns]

# %%
data=data.dropna() 

#remove data if null exists
 
data = data.select_dtypes(include=[np.number])

data.info() 
# Drop non-numeric columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 188637 entries, 0 to 188636
# Data columns (total 51 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   URLLength                   188637 non-null  int64
#  1   DomainLength                188637 non-null  int64
#  2   IsDomainIP                  188637 non-null  int64
#  3   URLSimilarityIndex          188637 non-null  float64
#  4   CharContinuationRate        188637 non-null  float64
#  5   TLDLegitimateProb           188637 non-null  float64
#  6   URLCharProb                 188637 non-null  float64
#  7   TLDLength                   188637 non-null  int64
#  8   NoOfSubDomain               188637 non-null  int64
#  9   HasObfuscation              188637 non-null  int64
#  10  NoOfObfuscatedChar          188637 non-null  int64
#  11  ObfuscationRatio            188637 non-null  float64
#  12  NoOfLettersInURL            188637 non-null  int64
#  13  LetterRatioInURL            188637 non-null  float64
#  14  NoOfDegitsInURL             188637 non-null  int64
#  15  DegitRatioInURL             188637 non-null  float64
#  16  NoOfEqualsInURL             188637 non-null  int64
#  17  NoOfQMarkInURL              188637 non-null  int64
#  18  NoOfAmpersandInURL          188637 non-null  int64
#  19  NoOfOtherSpecialCharsInURL  188637 non-null  int64
#  20  SpacialCharRatioInURL       188637 non-null  float64
#  21  IsHTTPS                     188637 non-null  int64
#  22  LineOfCode                  188637 non-null  int64
#  23  LargestLineLength           188637 non-null  int64
#  24  HasTitle                    188637 non-null  int64
#  25  DomainTitleMatchScore       188637 non-null  float64
#  26  URLTitleMatchScore          188637 non-null  float64
#  27  HasFavicon                  188637 non-null  int64
#  28  Robots                      188637 non-null  int64
#  29  IsResponsive                188637 non-null  int64
#  30  NoOfURLRedirect             188637 non-null  int64
#  31  NoOfSelfRedirect            188637 non-null  int64
#  32  HasDescription              188637 non-null  int64
#  33  NoOfPopup                   188637 non-null  int64
#  34  NoOfiFrame                  188637 non-null  int64
#  35  HasExternalFormSubmit       188637 non-null  int64
#  36  HasSocialNet                188637 non-null  int64
#  37  HasSubmitButton             188637 non-null  int64
#  38  HasHiddenFields             188637 non-null  int64
#  39  HasPasswordField            188637 non-null  int64
#  40  Bank                        188637 non-null  int64
#  41  Pay                         188637 non-null  int64
#  42  Crypto                      188637 non-null  int64
#  43  HasCopyrightInfo            188637 non-null  int64
#  44  NoOfImage                   188637 non-null  int64
#  45  NoOfCSS                     188637 non-null  int64
#  46  NoOfJS                      188637 non-null  int64
#  47  NoOfSelfRef                 188637 non-null  int64
#  48  NoOfEmptyRef                188637 non-null  int64
#  49  NoOfExternalRef             188637 non-null  int64
#  50  label                       188637 non-null  int64
# dtypes: float64(10), int64(41)
# memory usage: 73.4 MB

# %%
data["IsDomainIP"].value_counts()

#now we need to train the model using stratified train test split as we dont want the model to train 
#only on zeroes of the IsDomainIP feature🗿
# Out:
# IsDomainIP
# 0    188168
# 1       469
# Name: count, dtype: int64

# %%
from sklearn.model_selection import StratifiedShuffleSplit
Ssplit = StratifiedShuffleSplit(n_splits=1,random_state=42,test_size=0.2)
for trainIndex,testIndex in Ssplit.split(data,data["IsDomainIP"]):
    train=data.loc[trainIndex]
    test=data.loc[testIndex]

train["IsDomainIP"].value_counts()

#Now everything is fine😎
# Out:
# IsDomainIP
# 0    150534
# 1       375
# Name: count, dtype: int64

# %%
matrix=data.corr()
matrix["label"].sort_values()
#correlation of each feature wrt labels💀

#|value|>0.5 is considered that the label depends highly on that feature
# Out:
# SpacialCharRatioInURL        -0.534179
# DegitRatioInURL              -0.436415
# NoOfOtherSpecialCharsInURL   -0.377710
# LetterRatioInURL             -0.367976
# DomainLength                 -0.285115
# NoOfLettersInURL             -0.258596
# URLLength                    -0.238626
# NoOfDegitsInURL              -0.188991
# NoOfQMarkInURL               -0.177495
# NoOfEqualsInURL              -0.081870
# TLDLength                    -0.078300
# NoOfSelfRedirect             -0.075621
# IsDomainIP                   -0.059873
# HasObfuscation               -0.053596
# NoOfURLRedirect              -0.045521
# ObfuscationRatio             -0.042643
# LargestLineLength            -0.041393
# NoOfAmpersandInURL           -0.035685
# NoOfObfuscatedChar           -0.016223
# NoOfSubDomain                -0.004339
# NoOfPopup                     0.046579
# TLDLegitimateProb             0.096377
# Crypto                        0.096804
# NoOfEmptyRef                  0.103988
# HasPasswordField              0.135333
# HasExternalFormSubmit         0.164037
# Bank                          0.186779
# NoOfExternalRef               0.245984
# NoOfiFrame                    0.265330
# LineOfCode                    0.267379
# NoOfImage                     0.284226
# NoOfSelfRef                   0.296721
# Pay                           0.355191
# Robots                        0.387359
# NoOfCSS                       0.406142
# HasTitle                      0.464883
# CharContinuationRate          0.468576
# URLCharProb                   0.468956
# NoOfJS                        0.471331
# HasFavicon                    0.487833
# HasHiddenFields               0.501282
# URLTitleMatchScore            0.536632
# IsResponsive                  0.548472
# HasSubmitButton               0.572799
# DomainTitleMatchScore         0.581879
# IsHTTPS                       0.614960
# HasDescription                0.685045
# HasCopyrightInfo              0.738494
# HasSocialNet                  0.777756
# URLSimilarityIndex            0.863846
# label                         1.000000
# Name: label, dtype: float64

# %%
X_train=train.iloc[:,:-1].values
Y_train=train.iloc[:,-1:].values

X_test=test.iloc[:,:-1].values
Y_test=test.iloc[:,-1:].values

#Splitting X and Y

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

model=LogisticRegression()
model.fit(X_train,Y_train)

y_pred=model.predict(X_test)

#training the model and testing it 

accuracy = accuracy_score(Y_test, y_pred)
precision = precision_score(Y_test, y_pred)
recall = recall_score(Y_test, y_pred)
f1 = f1_score(Y_test, y_pred)

print(f"Accuracy: {accuracy:.2f}")
print(f"Precision: {precision:.2f}")
print(f"Recall: {recall:.2f}")
print(f"F1 Score: {f1:.2f}")

#Imagine getting accuracy and F1 score 1🗿
# Out:
# C:\Users\HP\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\utils\validation.py:1310: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Accuracy: 1.00
# Precision: 1.00
# Recall: 1.00
# F1 Score: 1.00
# C:\Users\HP\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
